# %% [markdown]
# # 2. Scaling Impact - Capital Gains
#
# **Feature:** `capital-gain` is 0 for most people but huge for some.
# **Goal:** Show how MinMax vs Standard vs Log scaling affects distance-based models (KNN).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer

columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 
           'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 
           'hours-per-week', 'native-country', 'income']
df = pd.read_csv('../data/raw/adult.data', names=columns, na_values=' ?', skipinitialspace=True)

sns.kdeplot(df['capital-gain'])
plt.title('Original Distribution (Heavily Skewed)')
plt.show()

# %%
# Log Transform Effect
df['log_gain'] = np.log1p(df['capital-gain'])
sns.kdeplot(df['log_gain'])
plt.title('Log Transformed')
plt.show()
